# %%
import json
import math
import csv

# %%
with open('RaptorsVHornets.json') as f:
    data = json.load(f)

events = data['events']

# %%
events[0]["home"]["players"]
# Out:
# [{'lastname': 'Johnson',
#   'firstname': 'James',
#   'playerid': 201949,
#   'jersey': '3',
#   'position': 'F'},
#  {'lastname': 'Scola',
#   'firstname': 'Luis',
#   'playerid': 2449,
#   'jersey': '4',
#   'position': 'F'},
#  {'lastname': 'Carroll',
#   'firstname': 'DeMarre',
#   'playerid': 201960,
#   'jersey': '5',
#   'position': 'F'},
#  {'lastname': 'Joseph',
#   'firstname': 'Cory',
#   'playerid': 202709,
#   'jersey': '6',
#   'position': 'G'},
#  {'lastname': 'Lowry',
#   'firstname': 'Kyle',
#   'playerid': 200768,
#   'jersey': '7',
#   'position': 'G'},
#  {'lastname': 'Biyombo',
#   'firstname': 'Bismack',
#   'playerid': 202687,
#   'jersey': '8',
#   'position': 'C-F'},
#  {'lastname': 'DeRozan',
#   'firstname': 'DeMar',
#   'playerid': 201942,
#   'jersey': '10',
#   'position': 'G'},
#  {'lastname': 'Valanciunas',
#   'firstname': 'Jonas',
#   'playerid': 202685,
#   'jersey': '17',
#   'position': 'C'},
#  {'lastname': 'Caboclo',
#   'firstname': 'Bruno',
#   'playerid': 203998,
#   'jersey': '20',
#   'position': 'F'},
#  {'lastname': 'Ross',
#   'firstname': 'Terrence',
#   'playerid': 203082,
#   'jersey': '31',
#   'position': 'F-G'},
#  {'lastname': 'Patterson',
#   'firstname': 'Patrick',
#   'playerid': 202335,
#   'jersey': '54',
#   'position': 'F'},
#  {'lastname': 'Wright',
#   'firstname': 'Delon',
#   'playerid': 1626153,
#   'jersey': '55',
#   'position': 'G'},
#  {'lastname': 'Nogueira',
#   'firstname': 'Lucas',
#   'playerid': 203512,
#   'jersey': '92',
#   'position': 'C'}]

# %%
home_players = events[0]["home"]["players"]
away_players = events[0]["visitor"]["players"]

with open('players.csv', 'w', newline='') as csvfile:
    fieldnames = ['player name', 'position', 'playerid']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for p in home_players:
        writer.writerow({
            'player name': f"{p['firstname']} {p['lastname']}",
            'position': p['position'],
            'playerid': p['playerid']
        })
    for x in away_players:
        writer.writerow({
            'player name': f"{x['firstname']} {x['lastname']}",
            'position': x['position'],
            'playerid': x['playerid']
        })

# %%
SHOT_HEIGHT_THRESHOLD = 3.0
BASKET_POSITIONS = [(4, 25, 10), (90, 25, 10)]  # Both baskets
SHOT_PROXIMITY_RADIUS = 3.0
MIN_TIME_BETWEEN_SHOTS = 1.0 # Minimum time in seconds between detected shots

# Standard quarter length in seconds (NBA quarters are 12 minutes)
QUARTER_LENGTH_SECONDS = 12 * 60

def distance3d(p1, p2):
    """Calculates the 3D Euclidean distance between two points."""
    return ((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2 + (p1[2]-p2[2])**2) ** 0.5

def distance2d(p1, p2):
    """Calculates the 2D Euclidean distance between two points (ignoring Z-axis)."""
    return ((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2) ** 0.5

def seconds_to_mmss(seconds):
    """Converts seconds into MM:SS.ms format."""
    minutes = int(seconds // 60)
    sec = seconds % 60
    return f"{minutes}:{sec:05.2f}"

def calculate_absolute_game_time(quarter, game_clock):
    """
    Calculates the total elapsed time in the game in seconds.
    game_clock is time remaining in the current quarter.
    """
    # Time elapsed in previous quarters
    time_from_previous_quarters = (quarter - 1) * QUARTER_LENGTH_SECONDS
    # Time elapsed in the current quarter
    time_elapsed_in_current_quarter = QUARTER_LENGTH_SECONDS - game_clock
    return time_from_previous_quarters + time_elapsed_in_current_quarter

shots = []
last_shot_absolute_time = None # This will now store the absolute game time of the last shot

# --- Start of your event processing loop (assuming 'events' is defined) ---
# Example 'events' structure for testing (replace with your actual data source):
# events = [{
#     'moments': [
#         # Quarter 1
#         [1, 0, 719.5, 0, 0, [[-1, -1, 47.5, 25.0, 1.0], [1, 201949, 40.0, 20.0, 0.0], [2, 2449, 50.0, 30.0, 0.0]]],
#         [1, 0, 710.0, 0, 0, [[-1, -1, 47.5, 25.0, 15.0], [1, 201949, 40.0, 20.0, 0.0], [2, 2449, 50.0, 30.0, 0.0]]], # Shot 1
#         [1, 0, 709.0, 0, 0, [[-1, -1, 47.5, 25.0, 1.0], [1, 201949, 40.0, 20.0, 0.0], [2, 2449, 50.0, 30.0, 0.0]]],
#         # Quarter 2
#         [2, 0, 719.0, 0, 0, [[-1, -1, 47.5, 25.0, 1.0], [1, 201949, 40.0, 20.0, 0.0], [2, 2449, 50.0, 30.0, 0.0]]],
#         [2, 0, 700.0, 0, 0, [[-1, -1, 47.5, 25.0, 12.0], [1, 201949, 40.0, 20.0, 0.0], [2, 2449, 50.0, 30.0, 0.0]]], # Shot 2
#         # Example with a box-out scenario
#         [2, 0, 690.0, 0, 0, [
#             [-1, -1, 47.5, 25.0, 1.0], # Ball
#             [1, 1001, 5.0, 25.0, 0.0],  # Boxer (Team 1, close to basket)
#             [2, 2002, 7.0, 26.0, 0.0],  # Target (Team 2, slightly further)
#             [1, 1003, 10.0, 20.0, 0.0], # Other player
#             [2, 2004, 12.0, 30.0, 0.0], # Other player
#         ]],
#         [2, 0, 685.0, 0, 0, [
#             [-1, -1, 47.5, 25.0, 15.0], # Ball at height (Shot 3)
#             [1, 1001, 5.0, 25.0, 0.0],
#             [2, 2002, 7.0, 26.0, 0.0],
#             [1, 1003, 10.0, 20.0, 0.0],
#             [2, 2004, 12.0, 30.0, 0.0],
#         ]],
#     ]
# }]
#
# If 'events' is not yet defined, you'll need to load it from your data source first.
# For instance, if 'events' comes from a JSON file:
# import json
# with open('your_events_data.json', 'r') as f:
#     events = json.load(f)


for event in events:
    current_shot_pending = False

    for moment in event.get('moments', []):
        quarter = moment[0]
        game_clock_in_quarter = moment[2] # This is the time remaining in the current quarter
        player_data = moment[5]

        # Calculate the absolute game time for the current moment
        current_absolute_time = calculate_absolute_game_time(quarter, game_clock_in_quarter)

        if not player_data or len(player_data) < 1:
            continue
        
        ball = player_data[0]
        ball_pos = (ball[2], ball[3], ball[4]) # (x, y, z)
        
        # Detect shot start: ball height crosses threshold
        if not current_shot_pending and ball_pos[2] >= SHOT_HEIGHT_THRESHOLD:
            current_shot_pending = True
        
        # If a shot is pending, check for proximity to basket and height
        if current_shot_pending:
            for i, basket_pos in enumerate(BASKET_POSITIONS):
                dist_to_basket = distance3d(ball_pos, basket_pos)
                
                # Check if ball is close to basket and at or above basket height
                if dist_to_basket <= SHOT_PROXIMITY_RADIUS and ball_pos[2] >= 10.0:
                    # Check if enough time has passed since the last detected shot
                    if (last_shot_absolute_time is None) or \
                       (current_absolute_time - last_shot_absolute_time >= MIN_TIME_BETWEEN_SHOTS):
                        
                        # --- Rebound / Box-out logic ---
                        
                        # Calculate player distances to basket
                        player_distances = []
                        for p in player_data:
                            if p[1] != -1: # Ensure it's a valid player, not ball
                                player_id = p[1]
                                player_x, player_y = p[2], p[3]
                                distance = distance2d((player_x, player_y), basket_pos[:2])
                                player_distances.append((player_id, distance))
                        
                        # Estimate offense and defense teams (based on player_data)
                        team_counts = {}
                        team_positions = {}

                        for p in player_data:
                            team_id = p[0]
                            player_id = p[1]
                            if player_id == -1: # Skip ball
                                continue
                            if team_id not in team_counts:
                                team_counts[team_id] = 0
                                team_positions[team_id] = []
                            team_counts[team_id] += 1
                            team_positions[team_id].append((p[2], p[3]))  # x, y

                        box_out_candidates = []
                        basket_xy = basket_pos[:2]

                        # Collect all valid cross-team pairs that meet the box out criteria
                        for i_p1, p1 in enumerate(player_data):
                            if p1[1] == -1: # Skip ball
                                continue
                            team1, id1, x1, y1 = p1[0], p1[1], p1[2], p1[3]
                            pos1 = (x1, y1)
                            dist1 = distance2d(pos1, basket_xy)

                            for i_p2, p2 in enumerate(player_data):
                                if p2[1] == -1 or p2[0] == team1: # Skip ball or same team
                                    continue
                                team2, id2, x2, y2 = p2[0], p2[1], p2[2], p2[3]
                                pos2 = (x2, y2)
                                dist2 = distance2d(pos2, basket_xy)
                                dist_between = distance2d(pos1, pos2)

                                # Only add if one player is clearly boxing out the other
                                # Criteria: Boxer is closer to basket, players are close, boxer is within reasonable distance
                                if dist1 < dist2 and dist_between <= 5 and dist1 <= 15:
                                    box_out_candidates.append({
                                        'BoxerID': id1,
                                        'TargetID': id2,
                                        'BoxerTeam': team1,
                                        'TargetTeam': team2,
                                        'BoxerDistanceToBasket': dist1,
                                        'TargetDistanceToBasket': dist2,
                                        'DistanceBetweenPlayers': dist_between
                                    })

                        # Resolve duplicates: only keep closest pair per player (either side)
                        box_outs = []
                        paired_ids = set()  # Keep track of players already involved in a box-out

                        # Sort all candidates by distance between players (closest first)
                        box_out_candidates.sort(key=lambda x: x['DistanceBetweenPlayers'])

                        for pair in box_out_candidates:
                            boxer = pair['BoxerID']
                            target = pair['TargetID']
                            # Add the pair only if neither player has been paired yet
                            if boxer not in paired_ids and target not in paired_ids:
                                box_outs.append(pair)
                                paired_ids.add(boxer)
                                paired_ids.add(target)

                        # --- End Rebound / Box-out logic ---

                        # Add full shot info including box outs
                        shots.append({
                            'Quarter': quarter,
                            # Store the raw numerical game_clock_in_quarter for CSV rounding
                            'GameClock': float(game_clock_in_quarter), # Ensure it's a float
                            'AbsoluteGameTime': current_absolute_time,
                            'Basket': 'Left' if i == 0 else 'Right',
                            'PlayerDistances': player_distances,
                            'BoxOuts': box_outs
                        })

                        last_shot_absolute_time = current_absolute_time # Update with absolute time
                    current_shot_pending = False # Reset shot pending state after a shot is detected
                    break  # No need to check both baskets once a shot is confirmed for one

# %%
shots
# Out:
# [{'Quarter': 1,
#   'GameClock': 701.5,
#   'AbsoluteGameTime': 18.5,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 7.227846134727828),
#    (201960, 23.47310544278494),
#    (200768, 30.37632073567337),
#    (201942, 36.489783655823445),
#    (202685, 5.33519194403538),
#    (101107, 3.3186989665831392),
#    (201587, 4.971868009239584),
#    (202689, 7.227846134727828),
#    (203469, 6.583314754749312),
#    (203798, 16.194342244388935)],
#   'BoxOuts': [{'BoxerID': 201587,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 4.971868009239584,
#     'TargetDistanceToBasket': 5.33519194403538,
#     'DistanceBetweenPlayers': 1.332788787542872}]},
#  {'Quarter': 1,
#   'GameClock': 686.03,
#   'AbsoluteGameTime': 33.97000000000003,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 18.910678555210545),
#    (201960, 4.972921642435154),
#    (200768, 11.980551791541156),
#    (201942, 6.097121948099774),
#    (202685, 5.763541187334394),
#    (101107, 33.00278095082444),
#    (201587, 12.922924504511354),
#    (202689, 24.545173965007866),
#    (203469, 1.12137980952039),
#    (203798, 34.56067346352209)],
#   'BoxOuts': [{'BoxerID': 200768,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 11.980551791541156,
#     'TargetDistanceToBasket': 12.922924504511354,
#     'DistanceBetweenPlayers': 4.584071187896195},
#    {'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.12137980952039,
#     'TargetDistanceToBasket': 5.763541187334394,
#     'DistanceBetweenPlayers': 4.737909024253212}]},
#  {'Quarter': 1,
#   'GameClock': 667.39,
#   'AbsoluteGameTime': 52.610000000000014,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 22.409249305777735),
#    (201960, 34.36567895944004),
#    (200768, 24.678561614893603),
#    (201942, 24.127569279935766),
#    (202685, 4.181001964852445),
#    (101107, 8.284257562002765),
#    (201587, 10.752000426934515),
#    (202689, 17.167834023082236),
#    (203469, 3.4390965909668783),
#    (203798, 10.232450979648034)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.4390965909668783,
#     'TargetDistanceToBasket': 4.181001964852445,
#     'DistanceBetweenPlayers': 1.5402754927934157}]},
#  {'Quarter': 1,
#   'GameClock': 659.28,
#   'AbsoluteGameTime': 60.72000000000003,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 7.972454693185783),
#    (201960, 11.415679468367184),
#    (200768, 10.95753578786764),
#    (201942, 4.621373797346414),
#    (202685, 6.627319017076204),
#    (101107, 30.266281041888842),
#    (201587, 12.732495518860393),
#    (202689, 30.38225934359227),
#    (203469, 9.10442212533008),
#    (203798, 25.088274002611254)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.10442212533008,
#     'TargetDistanceToBasket': 10.95753578786764,
#     'DistanceBetweenPlayers': 1.914750192845019}]},
#  {'Quarter': 1,
#   'GameClock': 633.0,
#   'AbsoluteGameTime': 87.0,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 10.396967071319406),
#    (201960, 10.586490936023136),
#    (200768, 16.468040495836167),
#    (201942, 23.776071196993417),
#    (202685, 25.75751969159298),
#    (101107, 7.549714791765315),
#    (201587, 13.399707469709925),
#    (202689, 29.48318807134839),
#    (203469, 7.222858515165585),
#    (203798, 27.45179444183932)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 201960,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 7.222858515165585,
#     'TargetDistanceToBasket': 10.586490936023136,
#     'DistanceBetweenPlayers': 3.681268299974888},
#    {'BoxerID': 2449,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 10.396967071319406,
#     'TargetDistanceToBasket': 13.399707469709925,
#     'DistanceBetweenPlayers': 3.727626064199572}]},
#  {'Quarter': 1,
#   'GameClock': 619.79,
#   'AbsoluteGameTime': 100.21000000000004,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 4.606793186512716),
#    (201960, 21.001155257385243),
#    (200768, 8.812397968067483),
#    (201942, 16.038213876345463),
#    (202685, 3.499344757422447),
#    (101107, 18.573453674610438),
#    (201587, 24.783545721395473),
#    (202689, 30.147430638488917),
#    (203469, 4.053348353559072),
#    (203798, 30.4147165904205)],
#   'BoxOuts': [{'BoxerID': 202685,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.499344757422447,
#     'TargetDistanceToBasket': 4.053348353559072,
#     'DistanceBetweenPlayers': 0.5908808790272445}]},
#  {'Quarter': 1,
#   'GameClock': 597.51,
#   'AbsoluteGameTime': 122.49000000000001,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 8.801613037903904),
#    (201960, 25.95288655954285),
#    (200768, 29.474094779334614),
#    (201942, 6.336992308169545),
#    (202685, 10.221249126995192),
#    (101107, 6.862724515817314),
#    (201587, 17.153464039132153),
#    (202689, 16.665509333761747),
#    (203469, 8.094589628937344),
#    (203798, 6.90229521653486)],
#   'BoxOuts': [{'BoxerID': 201942,
#     'TargetID': 203798,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 6.336992308169545,
#     'TargetDistanceToBasket': 6.90229521653486,
#     'DistanceBetweenPlayers': 1.9175778930724037},
#    {'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 8.094589628937344,
#     'TargetDistanceToBasket': 10.221249126995192,
#     'DistanceBetweenPlayers': 2.934903836584768},
#    {'BoxerID': 101107,
#     'TargetID': 2449,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.862724515817314,
#     'TargetDistanceToBasket': 8.801613037903904,
#     'DistanceBetweenPlayers': 4.735765615251666}]},
#  {'Quarter': 1,
#   'GameClock': 596.51,
#   'AbsoluteGameTime': 123.49000000000001,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 3.9425798731541257),
#    (201960, 26.56664079018836),
#    (200768, 35.85181740889853),
#    (201942, 4.691859094751247),
#    (202685, 12.640272135618755),
#    (101107, 3.154247523403958),
#    (201587, 19.30422690792874),
#    (202689, 13.930232354451235),
#    (203469, 10.202834968875075),
#    (203798, 7.322178284035427)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 2449,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.154247523403958,
#     'TargetDistanceToBasket': 3.9425798731541257,
#     'DistanceBetweenPlayers': 2.2203124947853623},
#    {'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 10.202834968875075,
#     'TargetDistanceToBasket': 12.640272135618755,
#     'DistanceBetweenPlayers': 2.5730680252570037},
#    {'BoxerID': 201942,
#     'TargetID': 203798,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.691859094751247,
#     'TargetDistanceToBasket': 7.322178284035427,
#     'DistanceBetweenPlayers': 3.2054010144442158}]},
#  {'Quarter': 1,
#   'GameClock': 594.27,
#   'AbsoluteGameTime': 125.73000000000002,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 3.061631429581294),
#    (201960, 34.52887234468569),
#    (200768, 38.424472661007336),
#    (201942, 12.789369713828748),
#    (202685, 12.64047501009357),
#    (101107, 2.3025363867917488),
#    (201587, 26.967781336164826),
#    (202689, 4.938795170049069),
#    (203469, 8.292796338901612),
#    (203798, 5.999142895489321)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 2449,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.3025363867917488,
#     'TargetDistanceToBasket': 3.061631429581294,
#     'DistanceBetweenPlayers': 1.7087170199011883}]},
#  {'Quarter': 1,
#   'GameClock': 588.35,
#   'AbsoluteGameTime': 131.64999999999998,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 15.88002626252551),
#    (201960, 16.22732354348677),
#    (200768, 11.29394983619548),
#    (201942, 25.304298071169647),
#    (202685, 2.55007508960031),
#    (101107, 25.45386265532601),
#    (201587, 25.230973154995425),
#    (202689, 7.6953463994416715),
#    (203469, 3.0970326057857376),
#    (203798, 33.32541168672939)],
#   'BoxOuts': [{'BoxerID': 202685,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 2.55007508960031,
#     'TargetDistanceToBasket': 3.0970326057857376,
#     'DistanceBetweenPlayers': 3.575809905084443},
#    {'BoxerID': 202689,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 7.6953463994416715,
#     'TargetDistanceToBasket': 11.29394983619548,
#     'DistanceBetweenPlayers': 4.378873922836786}]},
#  {'Quarter': 1,
#   'GameClock': 568.99,
#   'AbsoluteGameTime': 151.01,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 16.547671894042974),
#    (201960, 4.975767610811418),
#    (200768, 4.530146555388691),
#    (201942, 17.286732567243583),
#    (202685, 16.858264378283437),
#    (101107, 54.15973102319933),
#    (201587, 25.50566491687876),
#    (202689, 6.27485552127697),
#    (203469, 1.1174861574534116),
#    (203798, 31.612877657538544)],
#   'BoxOuts': [{'BoxerID': 201960,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.975767610811418,
#     'TargetDistanceToBasket': 6.27485552127697,
#     'DistanceBetweenPlayers': 2.533526316125418},
#    {'BoxerID': 203469,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.1174861574534116,
#     'TargetDistanceToBasket': 4.530146555388691,
#     'DistanceBetweenPlayers': 4.334965506206481}]},
#  {'Quarter': 1,
#   'GameClock': 554.47,
#   'AbsoluteGameTime': 165.52999999999997,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 19.694813809734278),
#    (201960, 23.690394209788913),
#    (200768, 34.692992991697906),
#    (201942, 24.30485851881677),
#    (202685, 12.398433490122853),
#    (101107, 8.591016788326048),
#    (201587, 6.964368583331874),
#    (202689, 20.491593506072192),
#    (203469, 8.349532963333935),
#    (203798, 21.95020375052815)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 8.349532963333935,
#     'TargetDistanceToBasket': 12.398433490122853,
#     'DistanceBetweenPlayers': 4.11940622153242}]},
#  {'Quarter': 1,
#   'GameClock': 536.51,
#   'AbsoluteGameTime': 183.49,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 17.088222620190784),
#    (201960, 7.728889205396853),
#    (200768, 12.347448502172417),
#    (201942, 11.972411015739477),
#    (202685, 6.667031189645055),
#    (101107, 31.66658965813654),
#    (201587, 23.141490779398804),
#    (202689, 21.72940913458072),
#    (203469, 26.30145262752801),
#    (203798, 26.192853215999584)],
#   'BoxOuts': []},
#  {'Quarter': 1,
#   'GameClock': 517.0,
#   'AbsoluteGameTime': 203.0,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 16.11404138104715),
#    (201960, 26.32048237137192),
#    (200768, 2.868241212886391),
#    (201942, 23.141612948705628),
#    (202685, 13.991630260713006),
#    (101107, 10.912888259090716),
#    (201587, 15.08551733801662),
#    (202689, 1.2143811183067696),
#    (203469, 9.910538805216396),
#    (203798, 9.654383534151728)],
#   'BoxOuts': [{'BoxerID': 202689,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.2143811183067696,
#     'TargetDistanceToBasket': 2.868241212886391,
#     'DistanceBetweenPlayers': 1.9950692644617618},
#    {'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.910538805216396,
#     'TargetDistanceToBasket': 13.991630260713006,
#     'DistanceBetweenPlayers': 4.134847028488474}]},
#  {'Quarter': 1,
#   'GameClock': 503.27,
#   'AbsoluteGameTime': 216.73000000000002,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 14.999678502167967),
#    (201960, 8.909493621356944),
#    (200768, 9.816672669749153),
#    (201942, 12.863525824104373),
#    (202685, 5.969091950347221),
#    (101107, 27.477206669778138),
#    (201587, 16.508992982087065),
#    (202689, 12.915600370629313),
#    (203469, 13.552612505672109),
#    (203798, 34.442095056487204)],
#   'BoxOuts': [{'BoxerID': 200768,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 9.816672669749153,
#     'TargetDistanceToBasket': 12.915600370629313,
#     'DistanceBetweenPlayers': 3.1084751861322664}]},
#  {'Quarter': 1,
#   'GameClock': 492.35,
#   'AbsoluteGameTime': 227.64999999999998,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 20.099649598786538),
#    (201960, 17.94567357249652),
#    (200768, 27.57565701325718),
#    (201942, 33.118019688770644),
#    (202685, 20.250690531132513),
#    (101107, 8.317496187056536),
#    (201587, 12.598814002615484),
#    (202689, 29.044413196334336),
#    (203469, 11.219175786955118),
#    (203798, 10.790816795465485)],
#   'BoxOuts': []},
#  {'Quarter': 1,
#   'GameClock': 471.32,
#   'AbsoluteGameTime': 248.68,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 24.14264052104078),
#    (201960, 29.207871904883792),
#    (200768, 37.42867494644714),
#    (201942, 30.11612975015548),
#    (202685, 7.224167894152239),
#    (101107, 8.08139258146144),
#    (201587, 11.982793176321621),
#    (202689, 21.5220688858971),
#    (203469, 22.803300235272964),
#    (203798, 6.347094575772447)],
#   'BoxOuts': [{'BoxerID': 203798,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.347094575772447,
#     'TargetDistanceToBasket': 7.224167894152239,
#     'DistanceBetweenPlayers': 1.5191157266317805}]},
#  {'Quarter': 1,
#   'GameClock': 450.36,
#   'AbsoluteGameTime': 269.64,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 9.15427978876001),
#    (201960, 15.430300830411568),
#    (200768, 7.010873854413587),
#    (201942, 9.841063384868523),
#    (202685, 2.808849012852064),
#    (101107, 29.771847814364833),
#    (201587, 22.081418294015894),
#    (202689, 20.931594145217417),
#    (203469, 1.7121972140206272),
#    (203798, 34.338969823524124)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.7121972140206272,
#     'TargetDistanceToBasket': 2.808849012852064,
#     'DistanceBetweenPlayers': 3.1413361654079655}]},
#  {'Quarter': 1,
#   'GameClock': 445.28,
#   'AbsoluteGameTime': 274.72,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 8.521903853652653),
#    (201960, 14.850122984032824),
#    (200768, 29.584342680717107),
#    (201942, 4.474127241149936),
#    (202685, 6.431305412628141),
#    (101107, 21.490076394496597),
#    (201587, 5.717374856015652),
#    (202689, 23.60446860959382),
#    (203469, 14.29479249285557),
#    (203798, 34.35561872288723)],
#   'BoxOuts': [{'BoxerID': 201942,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.474127241149936,
#     'TargetDistanceToBasket': 5.717374856015652,
#     'DistanceBetweenPlayers': 1.2829463443963725}]},
#  {'Quarter': 1,
#   'GameClock': 432.52,
#   'AbsoluteGameTime': 287.48,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 3.087339469251808),
#    (201960, 30.883425313357),
#    (200768, 25.977940673958354),
#    (201942, 7.184055491329393),
#    (202685, 43.72033100340389),
#    (101107, 3.473377083200153),
#    (201587, 25.454583829369515),
#    (202689, 9.158340426938713),
#    (203469, 45.42674649690201),
#    (203798, 10.776337252763579)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.473377083200153,
#     'TargetDistanceToBasket': 7.184055491329393,
#     'DistanceBetweenPlayers': 3.9999236101705757}]},
#  {'Quarter': 1,
#   'GameClock': 414.36,
#   'AbsoluteGameTime': 305.64,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 16.18753937444787),
#    (201960, 20.958694450478067),
#    (200768, 32.25897601633381),
#    (201942, 34.634427563812864),
#    (202685, 4.49926625062354),
#    (101107, 11.963675137256109),
#    (201587, 27.51475621386641),
#    (202689, 5.917007949335542),
#    (203469, 3.1620468309783134),
#    (203798, 11.926926373429158)],
#   'BoxOuts': [{'BoxerID': 202685,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.49926625062354,
#     'TargetDistanceToBasket': 5.917007949335542,
#     'DistanceBetweenPlayers': 1.5286984952239588},
#    {'BoxerID': 101107,
#     'TargetID': 2449,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 11.963675137256109,
#     'TargetDistanceToBasket': 16.18753937444787,
#     'DistanceBetweenPlayers': 4.253420029587957}]},
#  {'Quarter': 1,
#   'GameClock': 394.49,
#   'AbsoluteGameTime': 325.51,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 7.309493696782284),
#    (201960, 26.678099454430782),
#    (200768, 12.818201776489554),
#    (201942, 7.924884871769425),
#    (202685, 10.732543836733214),
#    (101107, 26.854450287326678),
#    (201587, 36.86804250662219),
#    (202689, 19.921909793302948),
#    (203469, 7.26108656090808),
#    (203798, 26.29458373647508)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 7.26108656090808,
#     'TargetDistanceToBasket': 7.924884871769425,
#     'DistanceBetweenPlayers': 1.5488750555806623}]},
#  {'Quarter': 1,
#   'GameClock': 386.29,
#   'AbsoluteGameTime': 333.71,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 25.763437583560158),
#    (201960, 16.930519548605115),
#    (200768, 28.972102939077445),
#    (201942, 33.627955193752115),
#    (202685, 4.389448453097495),
#    (101107, 25.500618079742694),
#    (201587, 9.069546141257565),
#    (202689, 20.155568764081057),
#    (203469, 4.588714740229556),
#    (203798, 12.417487488095166)],
#   'BoxOuts': [{'BoxerID': 202685,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.389448453097495,
#     'TargetDistanceToBasket': 4.588714740229556,
#     'DistanceBetweenPlayers': 1.4370010393872379}]},
#  {'Quarter': 1,
#   'GameClock': 374.0,
#   'AbsoluteGameTime': 346.0,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 7.2627148433213335),
#    (201960, 12.89382882954865),
#    (200768, 25.166090924029103),
#    (201942, 25.261145577453533),
#    (202685, 7.658426614683985),
#    (101107, 9.996864906164333),
#    (201587, 10.360235132949446),
#    (202689, 36.67107109958475),
#    (203469, 14.957742885582707),
#    (203798, 31.416834777591777)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 201960,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.996864906164333,
#     'TargetDistanceToBasket': 12.89382882954865,
#     'DistanceBetweenPlayers': 2.910494141722324},
#    {'BoxerID': 202685,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.658426614683985,
#     'TargetDistanceToBasket': 10.360235132949446,
#     'DistanceBetweenPlayers': 3.7854355300942606}]},
#  {'Quarter': 1,
#   'GameClock': 344.61,
#   'AbsoluteGameTime': 375.39,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 5.251505987704861),
#    (201960, 17.338069062095695),
#    (200768, 15.080594980135894),
#    (201942, 11.13077843968246),
#    (202685, 8.676229838195848),
#    (101107, 11.465673720392532),
#    (201587, 19.7076867482513),
#    (202689, 31.22195966490573),
#    (203469, 17.582871873254952),
#    (203798, 26.235711674450535)],
#   'BoxOuts': []},
#  {'Quarter': 1,
#   'GameClock': 319.97,
#   'AbsoluteGameTime': 400.03,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 13.099148899695736),
#    (201960, 30.13023203471888),
#    (200768, 15.395989993534029),
#    (201942, 22.38436056763963),
#    (202685, 6.206603248355738),
#    (101107, 32.11340026605716),
#    (201587, 12.425040065629567),
#    (202689, 8.480694874289489),
#    (203469, 9.57260233736365),
#    (203798, 5.164596246987756)],
#   'BoxOuts': [{'BoxerID': 203798,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.164596246987756,
#     'TargetDistanceToBasket': 6.206603248355738,
#     'DistanceBetweenPlayers': 1.2152248775021013},
#    {'BoxerID': 203469,
#     'TargetID': 2449,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.57260233736365,
#     'TargetDistanceToBasket': 13.099148899695736,
#     'DistanceBetweenPlayers': 4.210921034749998}]},
#  {'Quarter': 1,
#   'GameClock': 298.94,
#   'AbsoluteGameTime': 421.06,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 34.0458728937356),
#    (201960, 13.167809554774093),
#    (200768, 11.037919003621104),
#    (201942, 13.299994349547669),
#    (202685, 4.643059130056388),
#    (101107, 29.580942494400006),
#    (201587, 34.066016948491345),
#    (202689, 26.3885227188526),
#    (203469, 23.883647726178683),
#    (203798, 24.066144202038263)],
#   'BoxOuts': []},
#  {'Quarter': 1,
#   'GameClock': 285.94,
#   'AbsoluteGameTime': 434.06,
#   'Basket': 'Left',
#   'PlayerDistances': [(2449, 23.468840128723873),
#    (201960, 26.01737632944952),
#    (200768, 23.083105250561502),
#    (201942, 3.586583337174811),
#    (202685, 8.385213302534408),
#    (101107, 8.162779737375006),
#    (201587, 18.83271619368008),
#    (202689, 13.923776358933663),
#    (203469, 7.318520991491382),
#    (203798, 1.6667284501681743)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 7.318520991491382,
#     'TargetDistanceToBasket': 8.385213302534408,
#     'DistanceBetweenPlayers': 1.8031858782998509},
#    {'BoxerID': 203798,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.6667284501681743,
#     'TargetDistanceToBasket': 3.586583337174811,
#     'DistanceBetweenPlayers': 1.9220704911370956}]},
#  {'Quarter': 1,
#   'GameClock': 262.0,
#   'AbsoluteGameTime': 458.0,
#   'Basket': 'Right',
#   'PlayerDistances': [(2449, 6.474868280729731),
#    (200768, 28.997690163421634),
#    (201942, 26.060699674154954),
#    (203082, 12.104198839493677),
#    (202685, 8.319434067158655),
#    (201587, 11.010383163655108),
#    (202689, 31.134565599148804),
#    (203469, 15.040298435300416),
#    (1626163, 9.75955550916639),
#    (203798, 30.77762204208928)],
#   'BoxOuts': [{'BoxerID': 1626163,
#     'TargetID': 203082,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.75955550916639,
#     'TargetDistanceToBasket': 12.104198839493677,
#     'DistanceBetweenPlayers': 2.7265224148170915},
#    {'BoxerID': 2449,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 6.474868280729731,
#     'TargetDistanceToBasket': 11.010383163655108,
#     'DistanceBetweenPlayers': 4.721225602584564}]},
#  {'Quarter': 1,
#   'GameClock': 244.78,
#   'AbsoluteGameTime': 475.22,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 29.900897010639998),
#    (202335, 21.30172396569113),
#    (201942, 22.41027607470287),
#    (203082, 23.395825287315688),
#    (202685, 5.908596665207399),
#    (201587, 9.139091073514916),
#    (202689, 11.840475688045645),
#    (203469, 4.862307874168397),
#    (1626163, 13.293416158102477),
#    (203798, 19.377420487180434)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 4.862307874168397,
#     'TargetDistanceToBasket': 5.908596665207399,
#     'DistanceBetweenPlayers': 1.6678022642088}]},
#  {'Quarter': 1,
#   'GameClock': 227.9,
#   'AbsoluteGameTime': 492.1,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 10.468820417988832),
#    (202335, 16.878324604927467),
#    (201942, 4.065364574549245),
#    (203082, 40.063951997295526),
#    (202685, 5.493973666855351),
#    (201587, 10.70575417301369),
#    (202689, 29.615719013905434),
#    (203469, 6.100649946440133),
#    (1626163, 30.193150232875674),
#    (203798, 27.017731333422496)],
#   'BoxOuts': [{'BoxerID': 201942,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.065364574549245,
#     'TargetDistanceToBasket': 6.100649946440133,
#     'DistanceBetweenPlayers': 2.080398549557274}]},
#  {'Quarter': 1,
#   'GameClock': 221.22,
#   'AbsoluteGameTime': 498.78,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 6.767712049208354),
#    (202335, 12.701054478806077),
#    (201942, 3.1368666863129526),
#    (203082, 14.581174825013244),
#    (202685, 8.02912641462943),
#    (201587, 29.42608992620324),
#    (202689, 21.518446960189763),
#    (203469, 15.963432167062317),
#    (1626163, 3.078936685610801),
#    (203798, 10.442692395594158)],
#   'BoxOuts': [{'BoxerID': 1626163,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.078936685610801,
#     'TargetDistanceToBasket': 3.1368666863129526,
#     'DistanceBetweenPlayers': 1.6502043208342452},
#    {'BoxerID': 202335,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 12.701054478806077,
#     'TargetDistanceToBasket': 15.963432167062317,
#     'DistanceBetweenPlayers': 3.3440067120147936}]},
#  {'Quarter': 1,
#   'GameClock': 220.22,
#   'AbsoluteGameTime': 499.78,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 2.9520133069144494),
#    (202335, 10.651763377694797),
#    (201942, 5.309343263530809),
#    (203082, 12.479785552712835),
#    (202685, 4.766056802105906),
#    (201587, 32.14549001728859),
#    (202689, 21.28213719159098),
#    (203469, 22.150403802750418),
#    (1626163, 3.058445615831677),
#    (203798, 5.766400548175612)],
#   'BoxOuts': [{'BoxerID': 201942,
#     'TargetID': 203798,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 5.309343263530809,
#     'TargetDistanceToBasket': 5.766400548175612,
#     'DistanceBetweenPlayers': 0.7417353085838562},
#    {'BoxerID': 200768,
#     'TargetID': 1626163,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 2.9520133069144494,
#     'TargetDistanceToBasket': 3.058445615831677,
#     'DistanceBetweenPlayers': 1.6387307162557225}]},
#  {'Quarter': 1,
#   'GameClock': 193.29,
#   'AbsoluteGameTime': 526.71,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 8.317599770516734),
#    (202335, 10.010004123700442),
#    (201942, 9.045640311492601),
#    (203082, 24.151753129313406),
#    (202687, 7.134246110080589),
#    (202689, 22.485983422768065),
#    (203087, 23.034902160428203),
#    (203469, 9.702052591209759),
#    (1626163, 34.446750623912266),
#    (203798, 33.10407887250301)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.134246110080589,
#     'TargetDistanceToBasket': 9.702052591209759,
#     'DistanceBetweenPlayers': 2.8203315128899282}]},
#  {'Quarter': 1,
#   'GameClock': 173.33,
#   'AbsoluteGameTime': 546.67,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 10.575190597322585),
#    (202335, 26.496129077904946),
#    (201942, 30.498951110728385),
#    (203082, 24.481083704411454),
#    (202687, 3.01191968860393),
#    (202689, 6.884928264390267),
#    (203087, 7.102966716084204),
#    (203469, 4.460070423715303),
#    (1626163, 26.24429014353408),
#    (203798, 11.356391057197705)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.01191968860393,
#     'TargetDistanceToBasket': 4.460070423715303,
#     'DistanceBetweenPlayers': 1.4958260860474388},
#    {'BoxerID': 202689,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.884928264390267,
#     'TargetDistanceToBasket': 10.575190597322585,
#     'DistanceBetweenPlayers': 3.744920836613241}]},
#  {'Quarter': 1,
#   'GameClock': 165.41,
#   'AbsoluteGameTime': 554.59,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 11.054706012124424),
#    (202335, 6.0526219811334645),
#    (201942, 11.156953782556414),
#    (203082, 9.722487987326081),
#    (202687, 5.287648737662137),
#    (202689, 11.793729151960372),
#    (203087, 26.560084934195896),
#    (203469, 6.580337544510916),
#    (1626163, 23.65934750614438),
#    (203798, 30.610617542978446)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 5.287648737662137,
#     'TargetDistanceToBasket': 6.580337544510916,
#     'DistanceBetweenPlayers': 1.8238703599762787},
#    {'BoxerID': 201942,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 11.156953782556414,
#     'TargetDistanceToBasket': 11.793729151960372,
#     'DistanceBetweenPlayers': 2.5084649918426205}]},
#  {'Quarter': 1,
#   'GameClock': 155.57,
#   'AbsoluteGameTime': 564.4300000000001,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 29.54067233662768),
#    (202335, 23.385081313369426),
#    (201942, 3.81069216770392),
#    (203082, 24.304146062307968),
#    (202687, 10.283196006154895),
#    (202689, 18.3158745609403),
#    (203087, 6.166119749996751),
#    (203469, 5.593085458206409),
#    (1626163, 7.9745171770208145),
#    (203798, 2.3764049845302053)],
#   'BoxOuts': [{'BoxerID': 203798,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.3764049845302053,
#     'TargetDistanceToBasket': 3.81069216770392,
#     'DistanceBetweenPlayers': 2.0302032490615303}]},
#  {'Quarter': 1,
#   'GameClock': 146.61,
#   'AbsoluteGameTime': 573.39,
#   'Basket': 'Left',
#   'PlayerDistances': [(202335, 9.306595418159102),
#    (201942, 5.82206920888098),
#    (203082, 21.835739705208066),
#    (202709, 26.4831977743342),
#    (202687, 9.205154742756907),
#    (203148, 8.901151608842534),
#    (201946, 8.459321190320178),
#    (202689, 9.275787629479234),
#    (203087, 4.072883204856235),
#    (1626163, 5.649615319665579)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 8.459321190320178,
#     'TargetDistanceToBasket': 9.205154742756907,
#     'DistanceBetweenPlayers': 1.8907113848760742},
#    {'BoxerID': 203148,
#     'TargetID': 202335,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 8.901151608842534,
#     'TargetDistanceToBasket': 9.306595418159102,
#     'DistanceBetweenPlayers': 2.2788753595798092},
#    {'BoxerID': 1626163,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.649615319665579,
#     'TargetDistanceToBasket': 5.82206920888098,
#     'DistanceBetweenPlayers': 3.1905679911263443}]},
#  {'Quarter': 1,
#   'GameClock': 133.0,
#   'AbsoluteGameTime': 587.0,
#   'Basket': 'Left',
#   'PlayerDistances': [(202335, 31.9545503203065),
#    (201942, 15.955373744594642),
#    (203082, 30.650828575288138),
#    (202709, 30.466406123627387),
#    (202687, 24.850063150603862),
#    (203148, 26.438619836211192),
#    (201946, 30.37416298213006),
#    (202689, 26.074082720790006),
#    (203087, 25.807891074692638),
#    (1626163, 24.654146583658093)],
#   'BoxOuts': []},
#  {'Quarter': 1,
#   'GameClock': 122.75,
#   'AbsoluteGameTime': 597.25,
#   'Basket': 'Left',
#   'PlayerDistances': [(202335, 7.588231619040104),
#    (201942, 28.232853786696804),
#    (203082, 22.078994358958013),
#    (202709, 26.818026205062147),
#    (202687, 6.035543216281365),
#    (203148, 11.369750046069614),
#    (201946, 5.637752503560263),
#    (202689, 8.693689170473027),
#    (203087, 7.445875261552533),
#    (1626163, 8.748727439187942)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.637752503560263,
#     'TargetDistanceToBasket': 6.035543216281365,
#     'DistanceBetweenPlayers': 1.306151454694286},
#    {'BoxerID': 203087,
#     'TargetID': 202335,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 7.445875261552533,
#     'TargetDistanceToBasket': 7.588231619040104,
#     'DistanceBetweenPlayers': 2.2949671840791104}]},
#  {'Quarter': 1,
#   'GameClock': 104.0,
#   'AbsoluteGameTime': 616.0,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 10.260331099725779),
#    (201942, 26.94600660648809),
#    (203082, 13.624047122044908),
#    (202709, 25.867526073300866),
#    (202687, 7.559864119956125),
#    (203148, 15.202717586921748),
#    (201946, 10.183867597450396),
#    (202689, 32.1800771510573),
#    (203087, 31.478802928605788),
#    (1626163, 8.95594828272808)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.559864119956125,
#     'TargetDistanceToBasket': 10.183867597450396,
#     'DistanceBetweenPlayers': 3.013026545020809}]},
#  {'Quarter': 1,
#   'GameClock': 87.97,
#   'AbsoluteGameTime': 632.03,
#   'Basket': 'Left',
#   'PlayerDistances': [(202335, 5.713147926047425),
#    (201942, 22.8632443635303),
#    (203082, 22.950790720454492),
#    (202709, 27.1009154807619),
#    (202687, 3.4501669899441114),
#    (203148, 5.408348459825789),
#    (201946, 5.476143446961557),
#    (202689, 9.987587282241893),
#    (203087, 19.606592010163315),
#    (1626163, 3.840812140537467)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202335,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.476143446961557,
#     'TargetDistanceToBasket': 5.713147926047425,
#     'DistanceBetweenPlayers': 1.6746021605742651},
#    {'BoxerID': 202687,
#     'TargetID': 203148,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.4501669899441114,
#     'TargetDistanceToBasket': 5.408348459825789,
#     'DistanceBetweenPlayers': 2.0152500345118445}]},
#  {'Quarter': 1,
#   'GameClock': 76.93,
#   'AbsoluteGameTime': 643.0699999999999,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 4.990888507069657),
#    (201942, 14.838604744004739),
#    (203082, 16.770853956701185),
#    (202709, 7.7105615277747415),
#    (202687, 3.9271488166607558),
#    (203148, 23.073778006882616),
#    (201946, 8.886637595924569),
#    (202689, 3.582514877638331),
#    (203087, 25.2518142307934),
#    (1626163, 27.06225754265523)],
#   'BoxOuts': [{'BoxerID': 202689,
#     'TargetID': 202335,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.582514877638331,
#     'TargetDistanceToBasket': 4.990888507069657,
#     'DistanceBetweenPlayers': 2.8401007821026303}]},
#  {'Quarter': 1,
#   'GameClock': 66.25,
#   'AbsoluteGameTime': 653.75,
#   'Basket': 'Left',
#   'PlayerDistances': [(202335, 26.377967688281068),
#    (201942, 3.695414357727696),
#    (203082, 30.83501686735391),
#    (202709, 22.704504513245823),
#    (202687, 10.56942565149119),
#    (203148, 20.521421080393047),
#    (201946, 5.850667687366972),
#    (202689, 5.5441783949743195),
#    (203087, 9.26340690542092),
#    (1626163, 10.78157655011548)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 1626163,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 10.56942565149119,
#     'TargetDistanceToBasket': 10.78157655011548,
#     'DistanceBetweenPlayers': 1.2727290641766609},
#    {'BoxerID': 201942,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.695414357727696,
#     'TargetDistanceToBasket': 5.5441783949743195,
#     'DistanceBetweenPlayers': 2.179530054530107}]},
#  {'Quarter': 1,
#   'GameClock': 46.04,
#   'AbsoluteGameTime': 673.96,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 9.553414430558323),
#    (201942, 10.415370038131147),
#    (203082, 20.184102261953594),
#    (202709, 23.41687382517359),
#    (202687, 6.391535366607932),
#    (203148, 31.203599867786085),
#    (201946, 9.335894010950422),
#    (202689, 25.337068805773484),
#    (203087, 27.492149927606608),
#    (1626163, 23.634651217473042)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 6.391535366607932,
#     'TargetDistanceToBasket': 9.335894010950422,
#     'DistanceBetweenPlayers': 3.1998068464361995}]},
#  {'Quarter': 1,
#   'GameClock': 34.24,
#   'AbsoluteGameTime': 685.76,
#   'Basket': 'Left',
#   'PlayerDistances': [(202335, 26.792726980008958),
#    (201942, 3.2304203238897564),
#    (203082, 29.631160430487697),
#    (202709, 11.57034179626946),
#    (202687, 7.894120256577043),
#    (203148, 16.81819253825452),
#    (201946, 5.543137303919145),
#    (202689, 7.0004114428010595),
#    (203087, 7.178908435472624),
#    (1626163, 10.826284115397119)],
#   'BoxOuts': [{'BoxerID': 202689,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 7.0004114428010595,
#     'TargetDistanceToBasket': 7.894120256577043,
#     'DistanceBetweenPlayers': 2.194619746197504},
#    {'BoxerID': 201942,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.2304203238897564,
#     'TargetDistanceToBasket': 5.543137303919145,
#     'DistanceBetweenPlayers': 2.7451896570728955}]},
#  {'Quarter': 1,
#   'GameClock': 22.17,
#   'AbsoluteGameTime': 697.83,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 4.040618297798002),
#    (201942, 8.425323588670047),
#    (203082, 15.922907612933008),
#    (202709, 28.330325573738115),
#    (202687, 4.309689873598801),
#    (203148, 22.23632349927703),
#    (201946, 6.164130169764425),
#    (202689, 33.48025481525641),
#    (203087, 2.5057029273439397),
#    (1626163, 6.752959997527015)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 1626163,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.309689873598801,
#     'TargetDistanceToBasket': 6.752959997527015,
#     'DistanceBetweenPlayers': 2.47115191681936},
#    {'BoxerID': 203087,
#     'TargetID': 202335,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.5057029273439397,
#     'TargetDistanceToBasket': 4.040618297798002,
#     'DistanceBetweenPlayers': 3.5220044375894886}]},
#  {'Quarter': 1,
#   'GameClock': 21.17,
#   'AbsoluteGameTime': 698.83,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 4.830581998579464),
#    (201942, 6.278896725317275),
#    (203082, 16.876321026447087),
#    (202709, 24.373744336010418),
#    (202687, 4.650784157279279),
#    (203148, 21.446006294210118),
#    (201946, 3.0459637801031056),
#    (202689, 33.58738668265812),
#    (203087, 7.261009228784936),
#    (1626163, 7.50884989176105)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.0459637801031056,
#     'TargetDistanceToBasket': 4.650784157279279,
#     'DistanceBetweenPlayers': 2.269877958062938},
#    {'BoxerID': 202335,
#     'TargetID': 203087,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.830581998579464,
#     'TargetDistanceToBasket': 7.261009228784936,
#     'DistanceBetweenPlayers': 2.463660021451829}]},
#  {'Quarter': 1,
#   'GameClock': 19.65,
#   'AbsoluteGameTime': 700.35,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 3.971856195042815),
#    (201942, 5.1173136865351525),
#    (203082, 20.973363518599015),
#    (202709, 18.043606162654957),
#    (202687, 4.88961478443855),
#    (203148, 27.036881844926203),
#    (201946, 3.903986945905433),
#    (202689, 35.28901931497247),
#    (203087, 7.075521773247538),
#    (1626163, 13.499329039163394)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 3.903986945905433,
#     'TargetDistanceToBasket': 4.88961478443855,
#     'DistanceBetweenPlayers': 1.9776108108523296},
#    {'BoxerID': 201942,
#     'TargetID': 203087,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 5.1173136865351525,
#     'TargetDistanceToBasket': 7.075521773247538,
#     'DistanceBetweenPlayers': 3.2885866562552404},
#    {'BoxerID': 1626163,
#     'TargetID': 202709,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 13.499329039163394,
#     'TargetDistanceToBasket': 18.043606162654957,
#     'DistanceBetweenPlayers': 4.629148732304891}]},
#  {'Quarter': 1,
#   'GameClock': 2.77,
#   'AbsoluteGameTime': 717.23,
#   'Basket': 'Right',
#   'PlayerDistances': [(202335, 5.022867735467459),
#    (201942, 12.64769947607074),
#    (203082, 19.39764661624961),
#    (202709, 7.832525572923466),
#    (202687, 8.706563738817975),
#    (203148, 19.729186892444407),
#    (201946, 11.537730260363176),
#    (202689, 26.84247767307631),
#    (203087, 24.563343834376457),
#    (1626163, 18.50244030516245)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 8.706563738817975,
#     'TargetDistanceToBasket': 11.537730260363176,
#     'DistanceBetweenPlayers': 3.1879718589724115}]},
#  {'Quarter': 2,
#   'GameClock': 703.86,
#   'AbsoluteGameTime': 736.14,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 10.107422741851648),
#    (201949, 2.212081191660921),
#    (202335, 11.960501400045898),
#    (202709, 5.946782473253914),
#    (202687, 4.134397350545786),
#    (203148, 31.423844624763852),
#    (201946, 2.9043828269186602),
#    (201587, 10.864771595671032),
#    (203087, 27.290746470166408),
#    (1626163, 29.848573415265594)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.9043828269186602,
#     'TargetDistanceToBasket': 4.134397350545786,
#     'DistanceBetweenPlayers': 1.4366361907247052}]},
#  {'Quarter': 2,
#   'GameClock': 699.7,
#   'AbsoluteGameTime': 740.3,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 8.59914596839128),
#    (201949, 4.850128860968545),
#    (202335, 50.16652317283011),
#    (202709, 2.12435137491424),
#    (202687, 0.8049267525682114),
#    (203148, 44.532991790792586),
#    (201946, 1.9095670697830975),
#    (201587, 33.421426143418834),
#    (203087, 28.853562730231427),
#    (1626163, 45.21653228283876)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 0.8049267525682114,
#     'TargetDistanceToBasket': 1.9095670697830975,
#     'DistanceBetweenPlayers': 1.704632337191807}]},
#  {'Quarter': 2,
#   'GameClock': 695.78,
#   'AbsoluteGameTime': 744.22,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 4.3988498226240935),
#    (201949, 10.010000191533459),
#    (202335, 69.41770049175139),
#    (202709, 9.25174416717735),
#    (202687, 4.60478961527017),
#    (203148, 36.89283338216381),
#    (201946, 14.492097456700321),
#    (201587, 32.312030181684655),
#    (203087, 6.472573003535763),
#    (1626163, 38.12901150532492)],
#   'BoxOuts': [{'BoxerID': 200768,
#     'TargetID': 203087,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.3988498226240935,
#     'TargetDistanceToBasket': 6.472573003535763,
#     'DistanceBetweenPlayers': 2.1167672591241544}]},
#  {'Quarter': 2,
#   'GameClock': 679.78,
#   'AbsoluteGameTime': 760.22,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 27.76676484065978),
#    (201949, 35.37393081832439),
#    (202335, 5.3604080798480265),
#    (202709, 12.59959266103869),
#    (202687, 28.98308065394878),
#    (203148, 5.659606300600775),
#    (201946, 10.660479443256762),
#    (201587, 11.103403248779179),
#    (203087, 28.50671843579685),
#    (1626163, 2.6604919907603555)],
#   'BoxOuts': [{'BoxerID': 1626163,
#     'TargetID': 202335,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.6604919907603555,
#     'TargetDistanceToBasket': 5.3604080798480265,
#     'DistanceBetweenPlayers': 2.727820724387877}]},
#  {'Quarter': 2,
#   'GameClock': 660.58,
#   'AbsoluteGameTime': 779.42,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 16.341259324559413),
#    (201949, 14.446366373192259),
#    (202335, 7.497904659869985),
#    (202709, 3.028871158913825),
#    (202687, 0.9060891347433808),
#    (203148, 24.80633695697331),
#    (201946, 1.7986369073551263),
#    (201587, 30.578257686272774),
#    (203087, 26.410666224644924),
#    (1626163, 9.533056107419066)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202709,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.7986369073551263,
#     'TargetDistanceToBasket': 3.028871158913825,
#     'DistanceBetweenPlayers': 1.3068454366909592},
#    {'BoxerID': 202335,
#     'TargetID': 1626163,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.497904659869985,
#     'TargetDistanceToBasket': 9.533056107419066,
#     'DistanceBetweenPlayers': 2.9222213744512877}]},
#  {'Quarter': 2,
#   'GameClock': 659.58,
#   'AbsoluteGameTime': 780.42,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 21.33128886868536),
#    (201949, 17.487905460223075),
#    (202335, 13.666234616239393),
#    (202709, 5.013466761613168),
#    (202687, 2.180141162631445),
#    (203148, 25.149136187002526),
#    (201946, 3.8376206047106796),
#    (201587, 33.717613789064316),
#    (203087, 27.037851217820545),
#    (1626163, 18.89168877487135)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 2.180141162631445,
#     'TargetDistanceToBasket': 3.8376206047106796,
#     'DistanceBetweenPlayers': 1.8808890175924764}]},
#  {'Quarter': 2,
#   'GameClock': 634.57,
#   'AbsoluteGameTime': 805.43,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 36.93972508946162),
#    (201949, 11.668494776319694),
#    (202335, 25.077042116320257),
#    (202709, 22.984931796274704),
#    (202687, 12.684285913574326),
#    (203148, 14.402061619490452),
#    (201946, 9.51700634200692),
#    (201587, 6.735759814482698),
#    (203087, 28.097350165154364),
#    (1626163, 17.138931054374428)],
#   'BoxOuts': [{'BoxerID': 201946,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.51700634200692,
#     'TargetDistanceToBasket': 12.684285913574326,
#     'DistanceBetweenPlayers': 3.1872393838085067},
#    {'BoxerID': 201587,
#     'TargetID': 201949,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.735759814482698,
#     'TargetDistanceToBasket': 11.668494776319694,
#     'DistanceBetweenPlayers': 4.934328321727285}]},
#  {'Quarter': 2,
#   'GameClock': 616.67,
#   'AbsoluteGameTime': 823.33,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 16.2510818411483),
#    (201949, 9.54493949500991),
#    (202335, 8.198679093323504),
#    (202709, 9.337753458996445),
#    (202687, 4.146659874597869),
#    (203148, 27.443145833326025),
#    (201946, 5.507374482137565),
#    (201587, 26.410423225302548),
#    (203087, 11.6656235596088),
#    (1626163, 22.56686865312288)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 201946,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.146659874597869,
#     'TargetDistanceToBasket': 5.507374482137565,
#     'DistanceBetweenPlayers': 2.486753646765193},
#    {'BoxerID': 202709,
#     'TargetID': 203087,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 9.337753458996445,
#     'TargetDistanceToBasket': 11.6656235596088,
#     'DistanceBetweenPlayers': 2.792826783046158}]},
#  {'Quarter': 2,
#   'GameClock': 591.46,
#   'AbsoluteGameTime': 848.54,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 30.77592361761057),
#    (201949, 8.16994492031005),
#    (202335, 13.420715459382185),
#    (202709, 22.95918445008228),
#    (202687, 11.102769286885144),
#    (203148, 8.756685994427345),
#    (201946, 6.324913287192166),
#    (201587, 8.211086852006863),
#    (203087, 4.491744041349642),
#    (1626163, 8.120844213159122)],
#   'BoxOuts': [{'BoxerID': 201949,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 8.16994492031005,
# ...
#     'BoxerDistanceToBasket': 14.949547738995316,
#     'TargetDistanceToBasket': 16.612070101143324,
#     'DistanceBetweenPlayers': 2.894000544609486},
#    {'BoxerID': 202335,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.337469352692384,
#     'TargetDistanceToBasket': 11.731417323281956,
#     'DistanceBetweenPlayers': 4.401239522100565}]},
#  {'Quarter': 4,
#   'GameClock': 345.7,
#   'AbsoluteGameTime': 2534.3,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 35.74984135135707),
#    (202335, 23.328923956378695),
#    (201942, 22.927047296963472),
#    (203082, 3.4128371430966395),
#    (202687, 9.986185262931986),
#    (101107, 9.367944232162147),
#    (201587, 16.224485951638034),
#    (202689, 23.398327476366767),
#    (203087, 6.9067075141850305),
#    (203469, 5.260731748968012)],
#   'BoxOuts': [{'BoxerID': 203082,
#     'TargetID': 203087,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.4128371430966395,
#     'TargetDistanceToBasket': 6.9067075141850305,
#     'DistanceBetweenPlayers': 3.5835117828744423}]},
#  {'Quarter': 4,
#   'GameClock': 316.82,
#   'AbsoluteGameTime': 2563.18,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 14.244741720371767),
#    (202335, 30.692835033351027),
#    (201942, 15.655298081138538),
#    (203082, 7.457042322234734),
#    (202687, 6.641697373608647),
#    (101107, 31.35619624504541),
#    (201587, 22.706057015600486),
#    (202689, 29.963324718423685),
#    (203087, 5.157288330314682),
#    (203469, 16.080385053007905)],
#   'BoxOuts': [{'BoxerID': 203087,
#     'TargetID': 203082,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.157288330314682,
#     'TargetDistanceToBasket': 7.457042322234734,
#     'DistanceBetweenPlayers': 2.3036609023031147}]},
#  {'Quarter': 4,
#   'GameClock': 295.67,
#   'AbsoluteGameTime': 2584.33,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 28.146709824862306),
#    (202335, 31.401425794879124),
#    (201942, 30.094058551855383),
#    (203082, 27.243024683177158),
#    (202687, 6.44508846255038),
#    (101107, 10.236835138972392),
#    (201587, 9.469097213045178),
#    (202689, 8.09237279321708),
#    (203087, 24.21995290651904),
#    (203469, 5.3742450104549535)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.3742450104549535,
#     'TargetDistanceToBasket': 6.44508846255038,
#     'DistanceBetweenPlayers': 1.6298936040429255}]},
#  {'Quarter': 4,
#   'GameClock': 286.15,
#   'AbsoluteGameTime': 2593.85,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 12.882889769585862),
#    (202335, 29.690378798398648),
#    (201942, 11.828056285058),
#    (203082, 10.668156665685032),
#    (202687, 9.154166260501281),
#    (101107, 30.491392184957707),
#    (201587, 23.618064398093676),
#    (202689, 27.04436575554509),
#    (203087, 19.346964943706286),
#    (203469, 12.389108592388718)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 9.154166260501281,
#     'TargetDistanceToBasket': 12.389108592388718,
#     'DistanceBetweenPlayers': 3.334643851942812}]},
#  {'Quarter': 4,
#   'GameClock': 260.27,
#   'AbsoluteGameTime': 2619.73,
#   'Basket': 'Right',
#   'PlayerDistances': [(200768, 28.873426829042995),
#    (202335, 26.779426424748163),
#    (201942, 7.72577478656995),
#    (203082, 23.53200501860392),
#    (202687, 13.522000394564408),
#    (101107, 6.069806234551475),
#    (201587, 9.036992217043235),
#    (202689, 19.05148806241917),
#    (203087, 6.54288791737257),
#    (203469, 6.329068845146178)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.069806234551475,
#     'TargetDistanceToBasket': 7.72577478656995,
#     'DistanceBetweenPlayers': 2.381179554632536}]},
#  {'Quarter': 4,
#   'GameClock': 247.95,
#   'AbsoluteGameTime': 2632.05,
#   'Basket': 'Left',
#   'PlayerDistances': [(200768, 16.360853910490125),
#    (202335, 33.50571942229118),
#    (201942, 18.474238650710348),
#    (203082, 9.374805361334174),
#    (202687, 9.983402296902593),
#    (101107, 31.080609531457068),
#    (201587, 29.702019356902316),
#    (202689, 22.696722482794737),
#    (203087, 12.634987056977936),
#    (203469, 21.23737650770452)],
#   'BoxOuts': [{'BoxerID': 203082,
#     'TargetID': 203087,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 9.374805361334174,
#     'TargetDistanceToBasket': 12.634987056977936,
#     'DistanceBetweenPlayers': 3.507035784662028}]},
#  {'Quarter': 4,
#   'GameClock': 222.4,
#   'AbsoluteGameTime': 2657.6,
#   'Basket': 'Left',
#   'PlayerDistances': [(201960, 2.089848022823669),
#    (200768, 16.843959348339094),
#    (201942, 17.27217328828367),
#    (203082, 7.051375230024282),
#    (202687, 9.802581290996773),
#    (101107, 9.372980922470717),
#    (201587, 24.20743305719547),
#    (202689, 19.075659940104302),
#    (203087, 27.46248382912587),
#    (203469, 4.174658592148584)],
#   'BoxOuts': [{'BoxerID': 201960,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 2.089848022823669,
#     'TargetDistanceToBasket': 4.174658592148584,
#     'DistanceBetweenPlayers': 2.2473009414183944},
#    {'BoxerID': 203082,
#     'TargetID': 101107,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.051375230024282,
#     'TargetDistanceToBasket': 9.372980922470717,
#     'DistanceBetweenPlayers': 3.5364410614627815}]},
#  {'Quarter': 4,
#   'GameClock': 210.12,
#   'AbsoluteGameTime': 2669.88,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 13.640468036464148),
#    (200768, 30.388612810835905),
#    (201942, 30.305159954337807),
#    (203082, 15.560828054984732),
#    (202687, 2.9479673686117973),
#    (101107, 7.602562497276825),
#    (201587, 10.930070689368852),
#    (202689, 24.864613447075744),
#    (203087, 5.8382062748844366),
#    (203469, 4.047002583999667)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 2.9479673686117973,
#     'TargetDistanceToBasket': 4.047002583999667,
#     'DistanceBetweenPlayers': 1.2268026073089378}]},
#  {'Quarter': 4,
#   'GameClock': 187.49,
#   'AbsoluteGameTime': 2692.51,
#   'Basket': 'Left',
#   'PlayerDistances': [(201960, 22.025719663416222),
#    (200768, 17.80288286497723),
#    (201942, 5.610223361150606),
#    (203082, 8.141877143908522),
#    (202687, 4.903643584784685),
#    (101107, 23.560328176833615),
#    (201587, 36.57462727703182),
#    (202689, 28.78325964112126),
#    (203087, 17.619470170198085),
#    (203469, 9.834697657630354)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 4.903643584784685,
#     'TargetDistanceToBasket': 9.834697657630354,
#     'DistanceBetweenPlayers': 4.934338470149771}]},
#  {'Quarter': 4,
#   'GameClock': 175.65,
#   'AbsoluteGameTime': 2704.35,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 23.237752429165777),
#    (200768, 9.813137549030891),
#    (201942, 29.68163554787707),
#    (203082, 18.06762591953907),
#    (202687, 3.1960791003039932),
#    (101107, 18.416682665800593),
#    (201587, 30.582497228684584),
#    (202689, 3.3649620869335197),
#    (203087, 7.283608714215781),
#    (203469, 3.4379643503096466)],
#   'BoxOuts': [{'BoxerID': 202687,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.1960791003039932,
#     'TargetDistanceToBasket': 3.4379643503096466,
#     'DistanceBetweenPlayers': 1.9746342831522061}]},
#  {'Quarter': 4,
#   'GameClock': 152.1,
#   'AbsoluteGameTime': 2727.9,
#   'Basket': 'Left',
#   'PlayerDistances': [(201960, 13.878056129289144),
#    (200768, 13.751544432524662),
#    (201942, 19.89365091791097),
#    (203082, 6.444938140478929),
#    (202687, 7.507196890191439),
#    (101107, 24.914277897984523),
#    (201587, 27.71569488680556),
#    (202689, 35.15308946281251),
#    (203087, 25.884236724929714),
#    (203469, 24.108403033674797)],
#   'BoxOuts': []},
#  {'Quarter': 4,
#   'GameClock': 117.26,
#   'AbsoluteGameTime': 2762.74,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 23.02253054627141),
#    (200768, 18.96939406259726),
#    (201942, 29.164566275084567),
#    (203082, 42.02575107542755),
#    (202687, 6.384998265622322),
#    (101107, 5.524722370373012),
#    (201587, 22.239297425926026),
#    (202689, 11.076773753458175),
#    (203087, 10.895930245931277),
#    (203469, 26.982181243266826)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 202687,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 5.524722370373012,
#     'TargetDistanceToBasket': 6.384998265622322,
#     'DistanceBetweenPlayers': 1.568498347751761}]},
#  {'Quarter': 4,
#   'GameClock': 103.82,
#   'AbsoluteGameTime': 2776.1800000000003,
#   'Basket': 'Left',
#   'PlayerDistances': [(201960, 19.28307942851971),
#    (200768, 23.1537087684997),
#    (201942, 8.070721012555198),
#    (203082, 12.375965423432628),
#    (202687, 10.568503237223329),
#    (101107, 22.709988878150074),
#    (201587, 31.281126052265126),
#    (202689, 27.851139227044197),
#    (203087, 24.782970479998962),
#    (203469, 28.792151436599873)],
#   'BoxOuts': []},
#  {'Quarter': 4,
#   'GameClock': 81.74,
#   'AbsoluteGameTime': 2798.26,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 3.0633893924540496),
#    (200768, 24.296423357790754),
#    (201942, 33.32690160424908),
#    (203082, 21.12134955953573),
#    (202687, 15.81617442516995),
#    (101107, 18.89685834567482),
#    (201587, 3.494031127079441),
#    (202689, 21.558420550079735),
#    (203087, 8.407947711980608),
#    (203469, 8.120751752251763)],
#   'BoxOuts': [{'BoxerID': 201960,
#     'TargetID': 201587,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.0633893924540496,
#     'TargetDistanceToBasket': 3.494031127079441,
#     'DistanceBetweenPlayers': 1.7866201371304482}]},
#  {'Quarter': 4,
#   'GameClock': 50.63,
#   'AbsoluteGameTime': 2829.37,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 6.74006351110284),
#    (200768, 27.99660341901853),
#    (201942, 3.0781224748212974),
#    (203082, 21.749213259437685),
#    (202685, 3.2937026528209925),
#    (101107, 1.9819353098676074),
#    (201587, 15.448562003791812),
#    (202689, 11.208989932197278),
#    (203469, 2.286889464250512),
#    (1626163, 4.217221146169598)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.286889464250512,
#     'TargetDistanceToBasket': 3.0781224748212974,
#     'DistanceBetweenPlayers': 2.01614273624165},
#    {'BoxerID': 202685,
#     'TargetID': 1626163,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 3.2937026528209925,
#     'TargetDistanceToBasket': 4.217221146169598,
#     'DistanceBetweenPlayers': 2.6132314851348353},
#    {'BoxerID': 201960,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 6.74006351110284,
#     'TargetDistanceToBasket': 11.208989932197278,
#     'DistanceBetweenPlayers': 4.7401365941922}]},
#  {'Quarter': 4,
#   'GameClock': 49.63,
#   'AbsoluteGameTime': 2830.37,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 4.375430600352382),
#    (200768, 29.755774608793164),
#    (201942, 3.457639224239567),
#    (203082, 21.210829067931318),
#    (202685, 4.001282446116493),
#    (101107, 1.8869261707072673),
#    (201587, 15.294350699487048),
#    (202689, 7.945724058964036),
#    (203469, 15.265235676529862),
#    (1626163, 2.907822541662405)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 201942,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 1.8869261707072673,
#     'TargetDistanceToBasket': 3.457639224239567,
#     'DistanceBetweenPlayers': 1.5718309017512047},
#    {'BoxerID': 1626163,
#     'TargetID': 201960,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.907822541662405,
#     'TargetDistanceToBasket': 4.375430600352382,
#     'DistanceBetweenPlayers': 2.1559112377136476}]},
#  {'Quarter': 4,
#   'GameClock': 29.1,
#   'AbsoluteGameTime': 2850.9,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 43.874571133413944),
#    (200768, 11.307461609486007),
#    (201942, 15.045643125828812),
#    (203082, 30.153472316922304),
#    (202685, 4.4216761762141745),
#    (101107, 8.955125301440512),
#    (201587, 6.2331437987744165),
#    (202689, 23.271741862673274),
#    (203469, 2.59653242454239),
#    (203798, 17.948418882932277)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 2.59653242454239,
#     'TargetDistanceToBasket': 4.4216761762141745,
#     'DistanceBetweenPlayers': 1.8317231586132272},
#    {'BoxerID': 101107,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 8.955125301440512,
#     'TargetDistanceToBasket': 11.307461609486007,
#     'DistanceBetweenPlayers': 2.3598898038891485}]},
#  {'Quarter': 4,
#   'GameClock': 20.1,
#   'AbsoluteGameTime': 2859.9,
#   'Basket': 'Left',
#   'PlayerDistances': [(201960, 5.665718016571246),
#    (200768, 11.428312107612394),
#    (201942, 26.65693098929432),
#    (203082, 26.018035524345418),
#    (202685, 7.246697184021146),
#    (101107, 9.602090851996769),
#    (201587, 28.30406886356977),
#    (202689, 21.362309485521457),
#    (203469, 10.604230520589411),
#    (203798, 26.691289359448334)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 200768,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 9.602090851996769,
#     'TargetDistanceToBasket': 11.428312107612394,
#     'DistanceBetweenPlayers': 3.3477937452895747},
#    {'BoxerID': 202685,
#     'TargetID': 203469,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 7.246697184021146,
#     'TargetDistanceToBasket': 10.604230520589411,
#     'DistanceBetweenPlayers': 4.140568715345754}]},
#  {'Quarter': 4,
#   'GameClock': 16.3,
#   'AbsoluteGameTime': 2863.7,
#   'Basket': 'Right',
#   'PlayerDistances': [(201960, 33.3372889282392),
#    (200768, 16.106547324842776),
#    (201942, 22.973721470421378),
#    (203082, 9.321866035993004),
#    (202685, 8.835566999740314),
#    (101107, 6.847131250998479),
#    (201587, 12.611521179639674),
#    (202689, 28.38629418163984),
#    (203469, 6.676902066834588),
#    (203798, 34.892691841590555)],
#   'BoxOuts': [{'BoxerID': 203469,
#     'TargetID': 202685,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.676902066834588,
#     'TargetDistanceToBasket': 8.835566999740314,
#     'DistanceBetweenPlayers': 3.4229789956995123},
#    {'BoxerID': 101107,
#     'TargetID': 203082,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 6.847131250998479,
#     'TargetDistanceToBasket': 9.321866035993004,
#     'DistanceBetweenPlayers': 4.002627139792062}]},
#  {'Quarter': 4,
#   'GameClock': 6.9,
#   'AbsoluteGameTime': 2873.1,
#   'Basket': 'Left',
#   'PlayerDistances': [(201960, 22.412545777677735),
#    (200768, 9.356508543896062),
#    (201942, 20.11790588545438),
#    (203082, 16.16055157159247),
#    (202685, 8.314281300058353),
#    (101107, 14.491481079713695),
#    (201587, 38.147437207515004),
#    (202689, 9.695120704503887),
#    (203469, 28.166116138376267),
#    (203798, 31.308060735018387)],
#   'BoxOuts': [{'BoxerID': 101107,
#     'TargetID': 203082,
#     'BoxerTeam': 1610612766,
#     'TargetTeam': 1610612761,
#     'BoxerDistanceToBasket': 14.491481079713695,
#     'TargetDistanceToBasket': 16.16055157159247,
#     'DistanceBetweenPlayers': 2.547176005618771},
#    {'BoxerID': 200768,
#     'TargetID': 202689,
#     'BoxerTeam': 1610612761,
#     'TargetTeam': 1610612766,
#     'BoxerDistanceToBasket': 9.356508543896062,
#     'TargetDistanceToBasket': 9.695120704503887,
#     'DistanceBetweenPlayers': 3.4248500443815044}]}]

# %%
with open('shots_with_boxouts.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow([
        'Quarter',
        'Game Clock (s)',
        'Basket',
        'Boxer ID',
        'Target ID',
        'Boxer Team',
        'Target Team',
        'Boxer Distance to Basket (ft)',
        'Target Distance to Basket (ft)',
        'Distance Between Players (ft)'
    ])

    for shot in shots:
        for boxout in shot.get('BoxOuts', []):
            writer.writerow([
                f"Q{shot['Quarter']}",
                round(shot['GameClock'], 2),
                shot['Basket'],
                boxout['BoxerID'],
                boxout['TargetID'],
                boxout['BoxerTeam'],
                boxout['TargetTeam'],
                round(boxout['BoxerDistanceToBasket'], 2),
                round(boxout['TargetDistanceToBasket'], 2),
                round(boxout['DistanceBetweenPlayers'], 2)
            ])

# %%
if shots: # Only write if there are any shots detected
    with open('shots_with_boxouts.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow([
            'Quarter',
            'Game Clock (s)',
            'Basket',
            'Boxer ID',
            'Target ID',
            'Boxer Team',
            'Target Team',
            'Boxer Distance to Basket (ft)',
            'Target Distance to Basket (ft)',
            'Distance Between Players (ft)'
        ])

        for shot in shots:
            # Iterate through each boxout within the shot
            for boxout in shot.get('BoxOuts', []):
                writer.writerow([
                    f"Q{shot['Quarter']}", # Format Quarter as 'Q1', 'Q2', etc.
                    round(shot['GameClock'], 2), # Round the numerical game clock
                    shot['Basket'],
                    boxout['BoxerID'],
                    boxout['TargetID'],
                    boxout['BoxerTeam'],
                    boxout['TargetTeam'],
                    round(boxout['BoxerDistanceToBasket'], 2),
                    round(boxout['TargetDistanceToBasket'], 2),
                    round(boxout['DistanceBetweenPlayers'], 2)
                ])
    print("Box-out data successfully written to shots_with_boxouts.csv")
else:
    print("No shots with box-outs detected to write to CSV.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 22
#      17         for shot in shots:
#      18             # Iterate through each boxout within the shot
#      19             for boxout in shot.get('BoxOuts', []):
#      20                 writer.writerow([
#      21                     f"Q{shot['Quarter']}", # Format Quarter as 'Q1', 'Q2', etc.
# ---> 22                     round(shot['GameClock'], 2), # Round the numerical game clock
#      23                     shot['Basket'],
#      24                     boxout['BoxerID'],
#      25                     boxout['TargetID'],
#      26                     boxout['BoxerTeam'],
#      27                     boxout['TargetTeam'],
#      28                     round(boxout['BoxerDistanceToBasket'], 2),
#      29                     round(boxout['TargetDistanceToBasket'], 2),
#      30                     round(boxout['DistanceBetweenPlayers'], 2)
#      31                 ])
#      32     print("Box-out data successfully written to shots_with_boxouts.csv")
#      33 else:
#
# TypeError: type str doesn't define __round__ method
